# %%
import json

with open("./data/MSRVTT/metadata/test.json") as f:
    msrvtt_test_caps = json.load(f)

# %%
with open("./data/MSRVTT/metadata/test_video_captions.json", "w") as f:
    json.dump(msrvtt_test_caps, f, indent=4)
