# %%
# !python train.py
# Out:
# MODEL ID: MSVD = FEAT newBlip2ClsKF+newMViTv2+newImgCapBlip2KF fsl-9 mcl-20 = Transformer d-512 N_enc-0 N_dec-1 h-4 h_big-4 dp-0.1 = OPTIM lr-0.0001 warmup-3 gamma-0.5 pat-3 wd-5e-06 rg-0.6 = ep-1 bs-4 gc-5.0 bms-3 ls-0.15 = 1775240616
# Enter the load_video_feats method.
# ...
# 100%|█████████████████████████████████████| 1200/1200 [00:00<00:00, 1775.00it/s]
# Enter the load_video_feats method.
# ...
# 100%|███████████████████████████████████████| 100/100 [00:00<00:00, 1494.14it/s]
# Enter the load_video_feats method.
# ...
# 100%|███████████████████████████████████████| 670/670 [00:00<00:00, 1597.47it/s]
# #vocabs: 4116 (9614), #words: 339057 (345799). Trim words which appear less than 3 times.
# {'Total': 21201448, 'Trainable': 21201448}
#
#
#   0%|                                                 | 0/12195 [00:00<?, ?it/s]****************************************
# *           TRAIN ON 1 BATCH           *
# ****************************************
# +---------------- R2L_Decoder ----------------+
# ...
